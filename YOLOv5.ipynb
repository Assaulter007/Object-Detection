# %% [markdown]
# <a href="https://colab.research.google.com/github/Assaulter007/Object-Detection/blob/main/YOLOv5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <a align="left" href="https://ultralytics.com/yolov5" target="_blank">
# <img src="https://github.com/ultralytics/yolov5/releases/download/v1.0/splash_horizontal.png"></a>
#
# This is the **official YOLOv5 🚀 notebook** authored by **Ultralytics**, and is freely available for redistribution under the [GPL-3.0 license](https://choosealicense.com/licenses/gpl-3.0/).
# For more information please visit https://github.com/ultralytics/yolov5 and https://ultralytics.com. Thank you!

# %% [markdown]
# # Setup
#
# Clone repo, install dependencies and check PyTorch and GPU.

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone repo
# %cd yolov5
# %pip install -qr requirements.txt  # install dependencies

import torch
from IPython.display import Image, clear_output  # to display images

clear_output()
print(f"Setup complete. Using torch {torch.__version__} ({torch.cuda.get_device_properties(0).name if torch.cuda.is_available() else 'CPU'})")
# Out:
# Setup complete. Using torch 1.9.0+cu102 (Tesla T4)

# %%
# !rm -rf ../train_data/

# %%
# !unzip -q ../train_data.zip -d ../
# Out:
# replace ../train_data/image/test/00dea1edf14f09ab_jpg.rf.3f17c8790a68659d03b1939a59ccda80.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: A

# %% [markdown]
# # 1. Inference
#
# `detect.py` runs YOLOv5 inference on a variety of sources, downloading models automatically from the [latest YOLOv5 release](https://github.com/ultralytics/yolov5/releases), and saving results to `runs/detect`. Example inference sources are:
#
# <img src="https://user-images.githubusercontent.com/26833433/114307955-5c7e4e80-9ae2-11eb-9f50-a90e39bee53f.png" width="900">

# %%
# !python detect.py --weights runs/train/exp6/weights/best.pt --img 640 --conf 0.30 --source ../traffic.mp4
# Out:
# detect: weights=['runs/train/exp6/weights/best.pt'], source=../traffic.mp4, imgsz=640, conf_thres=0.3, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False
# YOLOv5 🚀 v5.0-276-gdabad57 torch 1.9.0+cu102 CUDA:0 (Tesla T4, 15109.75MB)
#
# Fusing layers...
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# Model Summary: 224 layers, 7064698 parameters, 0 gradients, 16.4 GFLOPs
# video 1/1 (1/899) /content/yolov5/../traffic.mp4: 384x640 13 Cars, Done. (0.012s)
# video 1/1 (2/899) /content/yolov5/../traffic.mp4: 384x640 13 Cars, Done. (0.011s)
# video 1/1 (3/899) /content/yolov5/../traffic.mp4: 384x640 13 Cars, Done. (0.011s)
# video 1/1 (4/899) /content/yolov5/../traffic.mp4: 384x640 13 Cars, Done. (0.011s)
# video 1/1 (5/899) /content/yolov5/../traffic.mp4: 384x640 13 Cars, Done. (0.011s)
# video 1/1 (6/899) /content/yolov5/../traffic.mp4: 384x640 13 Cars, Done. (0.011s)
# video 1/1 (7/899) /content/yolov5/../traffic.mp4: 384x640 14 Cars, Done. (0.011s)
# video 1/1 (8/899) /content/yolov5/../traffic.mp4: 384x640 13 Cars, Done. (0.011s)
# video 1/1 (9/899) /content/yolov5/../traffic.mp4: 384x640 13 Cars, Done. (0.011s)
# video 1/1 (10/899) /content/yolov5/../traffic.mp4: 384x640 12 Cars, Done. (0.011s)
# video 1/1 (11/899) /content/yolov5/../traffic.mp4: 384x640 12 Cars, Done. (0.011s)
# video 1/1 (12/899) /content/yolov5/../traffic.mp4: 384x640 11 Cars, Done. (0.011s)
# video 1/1 (13/899) /content/yolov5/../traffic.mp4: 384x640 11 Cars, Done. (0.010s)
# video 1/1 (14/899) /content/yolov5/../traffic.mp4: 384x640 11 Cars, Done. (0.010s)
# video 1/1 (15/899) /content/yolov5/../traffic.mp4: 384x640 12 Cars, Done. (0.010s)
# video 1/1 (16/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.010s)
# video 1/1 (17/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.010s)
# video 1/1 (18/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.010s)
# video 1/1 (19/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.010s)
# video 1/1 (20/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.010s)
# video 1/1 (21/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.010s)
# video 1/1 (22/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.010s)
# video 1/1 (23/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.009s)
# video 1/1 (24/899) /content/yolov5/../traffic.mp4: 384x640 12 Cars, Done. (0.009s)
# video 1/1 (25/899) /content/yolov5/../traffic.mp4: 384x640 12 Cars, Done. (0.010s)
# video 1/1 (26/899) /content/yolov5/../traffic.mp4: 384x640 11 Cars, Done. (0.009s)
# video 1/1 (27/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.010s)
# video 1/1 (28/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.009s)
# video 1/1 (29/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.009s)
# video 1/1 (30/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.009s)
# video 1/1 (31/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.009s)
# video 1/1 (32/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.009s)
# video 1/1 (33/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.009s)
# video 1/1 (34/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (35/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (36/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (37/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.009s)
# video 1/1 (38/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (39/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.009s)
# video 1/1 (40/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.009s)
# video 1/1 (41/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.009s)
# video 1/1 (42/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (43/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (44/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.009s)
# video 1/1 (45/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.009s)
# video 1/1 (46/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.009s)
# video 1/1 (47/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.010s)
# video 1/1 (48/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.009s)
# video 1/1 (49/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.009s)
# video 1/1 (50/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.009s)
# video 1/1 (51/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.009s)
# video 1/1 (52/899) /content/yolov5/../traffic.mp4: 384x640 11 Cars, Done. (0.009s)
# video 1/1 (53/899) /content/yolov5/../traffic.mp4: 384x640 11 Cars, Done. (0.009s)
# video 1/1 (54/899) /content/yolov5/../traffic.mp4: 384x640 11 Cars, Done. (0.009s)
# video 1/1 (55/899) /content/yolov5/../traffic.mp4: 384x640 11 Cars, Done. (0.009s)
# video 1/1 (56/899) /content/yolov5/../traffic.mp4: 384x640 11 Cars, Done. (0.009s)
# video 1/1 (57/899) /content/yolov5/../traffic.mp4: 384x640 11 Cars, Done. (0.009s)
# video 1/1 (58/899) /content/yolov5/../traffic.mp4: 384x640 11 Cars, Done. (0.009s)
# video 1/1 (59/899) /content/yolov5/../traffic.mp4: 384x640 11 Cars, Done. (0.009s)
# video 1/1 (60/899) /content/yolov5/../traffic.mp4: 384x640 11 Cars, Done. (0.009s)
# video 1/1 (61/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.009s)
# video 1/1 (62/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.009s)
# video 1/1 (63/899) /content/yolov5/../traffic.mp4: 384x640 11 Cars, Done. (0.009s)
# video 1/1 (64/899) /content/yolov5/../traffic.mp4: 384x640 11 Cars, Done. (0.009s)
# video 1/1 (65/899) /content/yolov5/../traffic.mp4: 384x640 11 Cars, Done. (0.009s)
# video 1/1 (66/899) /content/yolov5/../traffic.mp4: 384x640 14 Cars, Done. (0.009s)
# video 1/1 (67/899) /content/yolov5/../traffic.mp4: 384x640 13 Cars, Done. (0.009s)
# video 1/1 (68/899) /content/yolov5/../traffic.mp4: 384x640 13 Cars, Done. (0.009s)
# video 1/1 (69/899) /content/yolov5/../traffic.mp4: 384x640 14 Cars, Done. (0.011s)
# video 1/1 (70/899) /content/yolov5/../traffic.mp4: 384x640 14 Cars, Done. (0.009s)
# video 1/1 (71/899) /content/yolov5/../traffic.mp4: 384x640 13 Cars, Done. (0.009s)
# video 1/1 (72/899) /content/yolov5/../traffic.mp4: 384x640 12 Cars, Done. (0.009s)
# video 1/1 (73/899) /content/yolov5/../traffic.mp4: 384x640 13 Cars, Done. (0.010s)
# video 1/1 (74/899) /content/yolov5/../traffic.mp4: 384x640 13 Cars, Done. (0.009s)
# video 1/1 (75/899) /content/yolov5/../traffic.mp4: 384x640 11 Cars, Done. (0.009s)
# video 1/1 (76/899) /content/yolov5/../traffic.mp4: 384x640 12 Cars, Done. (0.009s)
# video 1/1 (77/899) /content/yolov5/../traffic.mp4: 384x640 12 Cars, Done. (0.010s)
# video 1/1 (78/899) /content/yolov5/../traffic.mp4: 384x640 12 Cars, Done. (0.009s)
# video 1/1 (79/899) /content/yolov5/../traffic.mp4: 384x640 12 Cars, Done. (0.009s)
# video 1/1 (80/899) /content/yolov5/../traffic.mp4: 384x640 11 Cars, Done. (0.009s)
# video 1/1 (81/899) /content/yolov5/../traffic.mp4: 384x640 11 Cars, Done. (0.009s)
# video 1/1 (82/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.009s)
# video 1/1 (83/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.009s)
# video 1/1 (84/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.009s)
# video 1/1 (85/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.009s)
# video 1/1 (86/899) /content/yolov5/../traffic.mp4: 384x640 11 Cars, Done. (0.009s)
# video 1/1 (87/899) /content/yolov5/../traffic.mp4: 384x640 11 Cars, Done. (0.009s)
# video 1/1 (88/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.009s)
# video 1/1 (89/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.009s)
# video 1/1 (90/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.009s)
# video 1/1 (91/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.009s)
# video 1/1 (92/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.009s)
# video 1/1 (93/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (94/899) /content/yolov5/../traffic.mp4: 384x640 8 Cars, Done. (0.010s)
# video 1/1 (95/899) /content/yolov5/../traffic.mp4: 384x640 8 Cars, Done. (0.009s)
# video 1/1 (96/899) /content/yolov5/../traffic.mp4: 384x640 8 Cars, Done. (0.009s)
# video 1/1 (97/899) /content/yolov5/../traffic.mp4: 384x640 7 Cars, Done. (0.009s)
# video 1/1 (98/899) /content/yolov5/../traffic.mp4: 384x640 8 Cars, Done. (0.009s)
# video 1/1 (99/899) /content/yolov5/../traffic.mp4: 384x640 8 Cars, Done. (0.009s)
# video 1/1 (100/899) /content/yolov5/../traffic.mp4: 384x640 8 Cars, Done. (0.009s)
# video 1/1 (101/899) /content/yolov5/../traffic.mp4: 384x640 8 Cars, Done. (0.009s)
# video 1/1 (102/899) /content/yolov5/../traffic.mp4: 384x640 7 Cars, Done. (0.009s)
# video 1/1 (103/899) /content/yolov5/../traffic.mp4: 384x640 6 Cars, Done. (0.009s)
# video 1/1 (104/899) /content/yolov5/../traffic.mp4: 384x640 7 Cars, Done. (0.009s)
# video 1/1 (105/899) /content/yolov5/../traffic.mp4: 384x640 7 Cars, Done. (0.009s)
# video 1/1 (106/899) /content/yolov5/../traffic.mp4: 384x640 6 Cars, Done. (0.009s)
# video 1/1 (107/899) /content/yolov5/../traffic.mp4: 384x640 6 Cars, Done. (0.009s)
# video 1/1 (108/899) /content/yolov5/../traffic.mp4: 384x640 6 Cars, Done. (0.009s)
# video 1/1 (109/899) /content/yolov5/../traffic.mp4: 384x640 6 Cars, Done. (0.009s)
# video 1/1 (110/899) /content/yolov5/../traffic.mp4: 384x640 7 Cars, Done. (0.009s)
# video 1/1 (111/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.009s)
# video 1/1 (112/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (113/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.010s)
# video 1/1 (114/899) /content/yolov5/../traffic.mp4: 384x640 8 Cars, Done. (0.009s)
# video 1/1 (115/899) /content/yolov5/../traffic.mp4: 384x640 8 Cars, Done. (0.009s)
# video 1/1 (116/899) /content/yolov5/../traffic.mp4: 384x640 7 Cars, Done. (0.009s)
# video 1/1 (117/899) /content/yolov5/../traffic.mp4: 384x640 7 Cars, Done. (0.009s)
# video 1/1 (118/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (119/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (120/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (121/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.010s)
# video 1/1 (122/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.009s)
# video 1/1 (123/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (124/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (125/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (126/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (127/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.009s)
# video 1/1 (128/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.009s)
# video 1/1 (129/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.009s)
# video 1/1 (130/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.009s)
# video 1/1 (131/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.009s)
# video 1/1 (132/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.009s)
# video 1/1 (133/899) /content/yolov5/../traffic.mp4: 384x640 11 Cars, Done. (0.009s)
# video 1/1 (134/899) /content/yolov5/../traffic.mp4: 384x640 12 Cars, Done. (0.010s)
# video 1/1 (135/899) /content/yolov5/../traffic.mp4: 384x640 12 Cars, Done. (0.010s)
# video 1/1 (136/899) /content/yolov5/../traffic.mp4: 384x640 12 Cars, Done. (0.010s)
# video 1/1 (137/899) /content/yolov5/../traffic.mp4: 384x640 12 Cars, Done. (0.010s)
# video 1/1 (138/899) /content/yolov5/../traffic.mp4: 384x640 12 Cars, Done. (0.010s)
# video 1/1 (139/899) /content/yolov5/../traffic.mp4: 384x640 12 Cars, Done. (0.009s)
# video 1/1 (140/899) /content/yolov5/../traffic.mp4: 384x640 11 Cars, Done. (0.009s)
# video 1/1 (141/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.010s)
# video 1/1 (142/899) /content/yolov5/../traffic.mp4: 384x640 11 Cars, Done. (0.010s)
# video 1/1 (143/899) /content/yolov5/../traffic.mp4: 384x640 11 Cars, Done. (0.010s)
# video 1/1 (144/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.010s)
# video 1/1 (145/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.010s)
# video 1/1 (146/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.010s)
# video 1/1 (147/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.010s)
# video 1/1 (148/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.009s)
# video 1/1 (149/899) /content/yolov5/../traffic.mp4: 384x640 12 Cars, Done. (0.009s)
# video 1/1 (150/899) /content/yolov5/../traffic.mp4: 384x640 12 Cars, Done. (0.010s)
# video 1/1 (151/899) /content/yolov5/../traffic.mp4: 384x640 11 Cars, Done. (0.009s)
# video 1/1 (152/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.009s)
# video 1/1 (153/899) /content/yolov5/../traffic.mp4: 384x640 11 Cars, Done. (0.009s)
# video 1/1 (154/899) /content/yolov5/../traffic.mp4: 384x640 12 Cars, Done. (0.010s)
# video 1/1 (155/899) /content/yolov5/../traffic.mp4: 384x640 12 Cars, Done. (0.010s)
# video 1/1 (156/899) /content/yolov5/../traffic.mp4: 384x640 12 Cars, Done. (0.010s)
# video 1/1 (157/899) /content/yolov5/../traffic.mp4: 384x640 12 Cars, Done. (0.010s)
# video 1/1 (158/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.010s)
# video 1/1 (159/899) /content/yolov5/../traffic.mp4: 384x640 11 Cars, Done. (0.009s)
# video 1/1 (160/899) /content/yolov5/../traffic.mp4: 384x640 11 Cars, Done. (0.009s)
# video 1/1 (161/899) /content/yolov5/../traffic.mp4: 384x640 11 Cars, Done. (0.009s)
# video 1/1 (162/899) /content/yolov5/../traffic.mp4: 384x640 11 Cars, Done. (0.009s)
# video 1/1 (163/899) /content/yolov5/../traffic.mp4: 384x640 11 Cars, Done. (0.009s)
# video 1/1 (164/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.010s)
# video 1/1 (165/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (166/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.009s)
# video 1/1 (167/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (168/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (169/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (170/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (171/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (172/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.009s)
# video 1/1 (173/899) /content/yolov5/../traffic.mp4: 384x640 8 Cars, Done. (0.009s)
# video 1/1 (174/899) /content/yolov5/../traffic.mp4: 384x640 8 Cars, Done. (0.009s)
# video 1/1 (175/899) /content/yolov5/../traffic.mp4: 384x640 8 Cars, Done. (0.010s)
# video 1/1 (176/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (177/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.009s)
# video 1/1 (178/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.009s)
# video 1/1 (179/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (180/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (181/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (182/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (183/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.009s)
# video 1/1 (184/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (185/899) /content/yolov5/../traffic.mp4: 384x640 11 Cars, Done. (0.009s)
# video 1/1 (186/899) /content/yolov5/../traffic.mp4: 384x640 11 Cars, Done. (0.009s)
# video 1/1 (187/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (188/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (189/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.009s)
# video 1/1 (190/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.009s)
# video 1/1 (191/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.009s)
# video 1/1 (192/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.009s)
# video 1/1 (193/899) /content/yolov5/../traffic.mp4: 384x640 11 Cars, Done. (0.009s)
# video 1/1 (194/899) /content/yolov5/../traffic.mp4: 384x640 11 Cars, Done. (0.009s)
# video 1/1 (195/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (196/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.009s)
# video 1/1 (197/899) /content/yolov5/../traffic.mp4: 384x640 11 Cars, Done. (0.009s)
# video 1/1 (198/899) /content/yolov5/../traffic.mp4: 384x640 11 Cars, Done. (0.009s)
# video 1/1 (199/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.009s)
# video 1/1 (200/899) /content/yolov5/../traffic.mp4: 384x640 13 Cars, Done. (0.010s)
# video 1/1 (201/899) /content/yolov5/../traffic.mp4: 384x640 13 Cars, Done. (0.009s)
# video 1/1 (202/899) /content/yolov5/../traffic.mp4: 384x640 12 Cars, Done. (0.009s)
# video 1/1 (203/899) /content/yolov5/../traffic.mp4: 384x640 12 Cars, Done. (0.009s)
# video 1/1 (204/899) /content/yolov5/../traffic.mp4: 384x640 12 Cars, Done. (0.009s)
# video 1/1 (205/899) /content/yolov5/../traffic.mp4: 384x640 11 Cars, Done. (0.009s)
# video 1/1 (206/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (207/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.009s)
# video 1/1 (208/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.009s)
# video 1/1 (209/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.009s)
# video 1/1 (210/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.009s)
# video 1/1 (211/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.009s)
# video 1/1 (212/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.009s)
# video 1/1 (213/899) /content/yolov5/../traffic.mp4: 384x640 11 Cars, Done. (0.009s)
# video 1/1 (214/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.009s)
# video 1/1 (215/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (216/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (217/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (218/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.009s)
# video 1/1 (219/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (220/899) /content/yolov5/../traffic.mp4: 384x640 8 Cars, Done. (0.009s)
# video 1/1 (221/899) /content/yolov5/../traffic.mp4: 384x640 11 Cars, Done. (0.009s)
# video 1/1 (222/899) /content/yolov5/../traffic.mp4: 384x640 11 Cars, Done. (0.009s)
# video 1/1 (223/899) /content/yolov5/../traffic.mp4: 384x640 11 Cars, Done. (0.009s)
# video 1/1 (224/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.009s)
# video 1/1 (225/899) /content/yolov5/../traffic.mp4: 384x640 11 Cars, Done. (0.009s)
# video 1/1 (226/899) /content/yolov5/../traffic.mp4: 384x640 11 Cars, Done. (0.009s)
# video 1/1 (227/899) /content/yolov5/../traffic.mp4: 384x640 11 Cars, Done. (0.009s)
# video 1/1 (228/899) /content/yolov5/../traffic.mp4: 384x640 11 Cars, Done. (0.009s)
# video 1/1 (229/899) /content/yolov5/../traffic.mp4: 384x640 11 Cars, Done. (0.009s)
# video 1/1 (230/899) /content/yolov5/../traffic.mp4: 384x640 11 Cars, Done. (0.009s)
# video 1/1 (231/899) /content/yolov5/../traffic.mp4: 384x640 11 Cars, Done. (0.009s)
# video 1/1 (232/899) /content/yolov5/../traffic.mp4: 384x640 11 Cars, Done. (0.009s)
# video 1/1 (233/899) /content/yolov5/../traffic.mp4: 384x640 11 Cars, Done. (0.009s)
# video 1/1 (234/899) /content/yolov5/../traffic.mp4: 384x640 11 Cars, Done. (0.009s)
# video 1/1 (235/899) /content/yolov5/../traffic.mp4: 384x640 12 Cars, Done. (0.009s)
# video 1/1 (236/899) /content/yolov5/../traffic.mp4: 384x640 13 Cars, Done. (0.009s)
# video 1/1 (237/899) /content/yolov5/../traffic.mp4: 384x640 13 Cars, Done. (0.010s)
# video 1/1 (238/899) /content/yolov5/../traffic.mp4: 384x640 13 Cars, Done. (0.009s)
# video 1/1 (239/899) /content/yolov5/../traffic.mp4: 384x640 14 Cars, Done. (0.009s)
# video 1/1 (240/899) /content/yolov5/../traffic.mp4: 384x640 14 Cars, Done. (0.009s)
# video 1/1 (241/899) /content/yolov5/../traffic.mp4: 384x640 14 Cars, Done. (0.009s)
# video 1/1 (242/899) /content/yolov5/../traffic.mp4: 384x640 14 Cars, Done. (0.009s)
# video 1/1 (243/899) /content/yolov5/../traffic.mp4: 384x640 14 Cars, Done. (0.009s)
# video 1/1 (244/899) /content/yolov5/../traffic.mp4: 384x640 14 Cars, Done. (0.010s)
# video 1/1 (245/899) /content/yolov5/../traffic.mp4: 384x640 14 Cars, Done. (0.009s)
# video 1/1 (246/899) /content/yolov5/../traffic.mp4: 384x640 14 Cars, Done. (0.009s)
# video 1/1 (247/899) /content/yolov5/../traffic.mp4: 384x640 14 Cars, Done. (0.009s)
# video 1/1 (248/899) /content/yolov5/../traffic.mp4: 384x640 12 Cars, Done. (0.009s)
# video 1/1 (249/899) /content/yolov5/../traffic.mp4: 384x640 12 Cars, Done. (0.009s)
# video 1/1 (250/899) /content/yolov5/../traffic.mp4: 384x640 12 Cars, Done. (0.009s)
# video 1/1 (251/899) /content/yolov5/../traffic.mp4: 384x640 11 Cars, Done. (0.009s)
# video 1/1 (252/899) /content/yolov5/../traffic.mp4: 384x640 11 Cars, Done. (0.009s)
# video 1/1 (253/899) /content/yolov5/../traffic.mp4: 384x640 12 Cars, Done. (0.009s)
# video 1/1 (254/899) /content/yolov5/../traffic.mp4: 384x640 12 Cars, Done. (0.009s)
# video 1/1 (255/899) /content/yolov5/../traffic.mp4: 384x640 11 Cars, Done. (0.009s)
# video 1/1 (256/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.009s)
# video 1/1 (257/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.009s)
# video 1/1 (258/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.009s)
# video 1/1 (259/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (260/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (261/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (262/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (263/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.009s)
# video 1/1 (264/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (265/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.009s)
# video 1/1 (266/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.009s)
# video 1/1 (267/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.009s)
# video 1/1 (268/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.009s)
# video 1/1 (269/899) /content/yolov5/../traffic.mp4: 384x640 11 Cars, Done. (0.009s)
# video 1/1 (270/899) /content/yolov5/../traffic.mp4: 384x640 11 Cars, Done. (0.009s)
# video 1/1 (271/899) /content/yolov5/../traffic.mp4: 384x640 11 Cars, Done. (0.009s)
# video 1/1 (272/899) /content/yolov5/../traffic.mp4: 384x640 11 Cars, Done. (0.009s)
# video 1/1 (273/899) /content/yolov5/../traffic.mp4: 384x640 11 Cars, Done. (0.009s)
# video 1/1 (274/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.010s)
# video 1/1 (275/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.009s)
# video 1/1 (276/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.009s)
# video 1/1 (277/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.009s)
# video 1/1 (278/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.009s)
# video 1/1 (279/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.009s)
# video 1/1 (280/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.010s)
# video 1/1 (281/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.009s)
# video 1/1 (282/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.009s)
# video 1/1 (283/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.009s)
# video 1/1 (284/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.009s)
# video 1/1 (285/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (286/899) /content/yolov5/../traffic.mp4: 384x640 8 Cars, Done. (0.009s)
# video 1/1 (287/899) /content/yolov5/../traffic.mp4: 384x640 8 Cars, Done. (0.009s)
# video 1/1 (288/899) /content/yolov5/../traffic.mp4: 384x640 8 Cars, Done. (0.009s)
# video 1/1 (289/899) /content/yolov5/../traffic.mp4: 384x640 8 Cars, Done. (0.010s)
# video 1/1 (290/899) /content/yolov5/../traffic.mp4: 384x640 8 Cars, Done. (0.009s)
# video 1/1 (291/899) /content/yolov5/../traffic.mp4: 384x640 8 Cars, Done. (0.009s)
# video 1/1 (292/899) /content/yolov5/../traffic.mp4: 384x640 8 Cars, Done. (0.009s)
# video 1/1 (293/899) /content/yolov5/../traffic.mp4: 384x640 8 Cars, Done. (0.009s)
# video 1/1 (294/899) /content/yolov5/../traffic.mp4: 384x640 8 Cars, Done. (0.009s)
# video 1/1 (295/899) /content/yolov5/../traffic.mp4: 384x640 7 Cars, Done. (0.009s)
# video 1/1 (296/899) /content/yolov5/../traffic.mp4: 384x640 7 Cars, Done. (0.009s)
# video 1/1 (297/899) /content/yolov5/../traffic.mp4: 384x640 7 Cars, Done. (0.009s)
# video 1/1 (298/899) /content/yolov5/../traffic.mp4: 384x640 6 Cars, Done. (0.009s)
# video 1/1 (299/899) /content/yolov5/../traffic.mp4: 384x640 6 Cars, Done. (0.009s)
# video 1/1 (300/899) /content/yolov5/../traffic.mp4: 384x640 6 Cars, Done. (0.009s)
# video 1/1 (301/899) /content/yolov5/../traffic.mp4: 384x640 8 Cars, Done. (0.009s)
# video 1/1 (302/899) /content/yolov5/../traffic.mp4: 384x640 8 Cars, Done. (0.009s)
# video 1/1 (303/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (304/899) /content/yolov5/../traffic.mp4: 384x640 8 Cars, Done. (0.009s)
# video 1/1 (305/899) /content/yolov5/../traffic.mp4: 384x640 8 Cars, Done. (0.009s)
# video 1/1 (306/899) /content/yolov5/../traffic.mp4: 384x640 8 Cars, Done. (0.009s)
# video 1/1 (307/899) /content/yolov5/../traffic.mp4: 384x640 8 Cars, Done. (0.009s)
# video 1/1 (308/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (309/899) /content/yolov5/../traffic.mp4: 384x640 8 Cars, Done. (0.009s)
# video 1/1 (310/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (311/899) /content/yolov5/../traffic.mp4: 384x640 8 Cars, Done. (0.009s)
# video 1/1 (312/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (313/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (314/899) /content/yolov5/../traffic.mp4: 384x640 7 Cars, Done. (0.009s)
# video 1/1 (315/899) /content/yolov5/../traffic.mp4: 384x640 8 Cars, Done. (0.009s)
# video 1/1 (316/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (317/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (318/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.009s)
# video 1/1 (319/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.011s)
# video 1/1 (320/899) /content/yolov5/../traffic.mp4: 384x640 8 Cars, Done. (0.009s)
# video 1/1 (321/899) /content/yolov5/../traffic.mp4: 384x640 8 Cars, Done. (0.009s)
# video 1/1 (322/899) /content/yolov5/../traffic.mp4: 384x640 8 Cars, Done. (0.009s)
# video 1/1 (323/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (324/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.009s)
# video 1/1 (325/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.009s)
# video 1/1 (326/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (327/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.009s)
# video 1/1 (328/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.009s)
# video 1/1 (329/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.009s)
# video 1/1 (330/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (331/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (332/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.010s)
# video 1/1 (333/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (334/899) /content/yolov5/../traffic.mp4: 384x640 8 Cars, Done. (0.009s)
# video 1/1 (335/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.009s)
# video 1/1 (336/899) /content/yolov5/../traffic.mp4: 384x640 8 Cars, Done. (0.009s)
# video 1/1 (337/899) /content/yolov5/../traffic.mp4: 384x640 8 Cars, Done. (0.009s)
# video 1/1 (338/899) /content/yolov5/../traffic.mp4: 384x640 8 Cars, Done. (0.009s)
# video 1/1 (339/899) /content/yolov5/../traffic.mp4: 384x640 8 Cars, Done. (0.009s)
# video 1/1 (340/899) /content/yolov5/../traffic.mp4: 384x640 6 Cars, Done. (0.009s)
# video 1/1 (341/899) /content/yolov5/../traffic.mp4: 384x640 7 Cars, Done. (0.009s)
# video 1/1 (342/899) /content/yolov5/../traffic.mp4: 384x640 7 Cars, Done. (0.009s)
# video 1/1 (343/899) /content/yolov5/../traffic.mp4: 384x640 7 Cars, Done. (0.009s)
# video 1/1 (344/899) /content/yolov5/../traffic.mp4: 384x640 7 Cars, Done. (0.010s)
# video 1/1 (345/899) /content/yolov5/../traffic.mp4: 384x640 8 Cars, Done. (0.009s)
# video 1/1 (346/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (347/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (348/899) /content/yolov5/../traffic.mp4: 384x640 8 Cars, Done. (0.009s)
# video 1/1 (349/899) /content/yolov5/../traffic.mp4: 384x640 8 Cars, Done. (0.009s)
# video 1/1 (350/899) /content/yolov5/../traffic.mp4: 384x640 7 Cars, Done. (0.009s)
# video 1/1 (351/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (352/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.009s)
# video 1/1 (353/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.009s)
# video 1/1 (354/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (355/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (356/899) /content/yolov5/../traffic.mp4: 384x640 8 Cars, Done. (0.009s)
# video 1/1 (357/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.009s)
# video 1/1 (358/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.009s)
# video 1/1 (359/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.009s)
# video 1/1 (360/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.009s)
# video 1/1 (361/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.009s)
# video 1/1 (362/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.009s)
# video 1/1 (363/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.009s)
# video 1/1 (364/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (365/899) /content/yolov5/../traffic.mp4: 384x640 8 Cars, Done. (0.009s)
# video 1/1 (366/899) /content/yolov5/../traffic.mp4: 384x640 8 Cars, Done. (0.009s)
# video 1/1 (367/899) /content/yolov5/../traffic.mp4: 384x640 8 Cars, Done. (0.009s)
# video 1/1 (368/899) /content/yolov5/../traffic.mp4: 384x640 8 Cars, Done. (0.009s)
# video 1/1 (369/899) /content/yolov5/../traffic.mp4: 384x640 8 Cars, Done. (0.009s)
# video 1/1 (370/899) /content/yolov5/../traffic.mp4: 384x640 8 Cars, Done. (0.009s)
# video 1/1 (371/899) /content/yolov5/../traffic.mp4: 384x640 8 Cars, Done. (0.009s)
# video 1/1 (372/899) /content/yolov5/../traffic.mp4: 384x640 8 Cars, Done. (0.009s)
# video 1/1 (373/899) /content/yolov5/../traffic.mp4: 384x640 8 Cars, Done. (0.009s)
# video 1/1 (374/899) /content/yolov5/../traffic.mp4: 384x640 8 Cars, Done. (0.009s)
# video 1/1 (375/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (376/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (377/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.009s)
# video 1/1 (378/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.009s)
# video 1/1 (379/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.009s)
# video 1/1 (380/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.009s)
# video 1/1 (381/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (382/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (383/899) /content/yolov5/../traffic.mp4: 384x640 8 Cars, Done. (0.009s)
# video 1/1 (384/899) /content/yolov5/../traffic.mp4: 384x640 8 Cars, Done. (0.009s)
# video 1/1 (385/899) /content/yolov5/../traffic.mp4: 384x640 8 Cars, Done. (0.009s)
# video 1/1 (386/899) /content/yolov5/../traffic.mp4: 384x640 8 Cars, Done. (0.009s)
# video 1/1 (387/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (388/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (389/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (390/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (391/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (392/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (393/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (394/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (395/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (396/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (397/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (398/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (399/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.009s)
# video 1/1 (400/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.009s)
# video 1/1 (401/899) /content/yolov5/../traffic.mp4: 384x640 11 Cars, Done. (0.009s)
# video 1/1 (402/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.009s)
# video 1/1 (403/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.009s)
# video 1/1 (404/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.009s)
# video 1/1 (405/899) /content/yolov5/../traffic.mp4: 384x640 11 Cars, Done. (0.009s)
# video 1/1 (406/899) /content/yolov5/../traffic.mp4: 384x640 12 Cars, Done. (0.009s)
# video 1/1 (407/899) /content/yolov5/../traffic.mp4: 384x640 12 Cars, Done. (0.009s)
# video 1/1 (408/899) /content/yolov5/../traffic.mp4: 384x640 11 Cars, Done. (0.009s)
# video 1/1 (409/899) /content/yolov5/../traffic.mp4: 384x640 11 Cars, Done. (0.009s)
# video 1/1 (410/899) /content/yolov5/../traffic.mp4: 384x640 11 Cars, Done. (0.009s)
# video 1/1 (411/899) /content/yolov5/../traffic.mp4: 384x640 11 Cars, Done. (0.009s)
# video 1/1 (412/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.009s)
# video 1/1 (413/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.009s)
# video 1/1 (414/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (415/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (416/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (417/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.009s)
# video 1/1 (418/899) /content/yolov5/../traffic.mp4: 384x640 11 Cars, Done. (0.009s)
# video 1/1 (419/899) /content/yolov5/../traffic.mp4: 384x640 11 Cars, Done. (0.009s)
# video 1/1 (420/899) /content/yolov5/../traffic.mp4: 384x640 11 Cars, Done. (0.009s)
# video 1/1 (421/899) /content/yolov5/../traffic.mp4: 384x640 11 Cars, Done. (0.009s)
# video 1/1 (422/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.009s)
# video 1/1 (423/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (424/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (425/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (426/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (427/899) /content/yolov5/../traffic.mp4: 384x640 8 Cars, Done. (0.009s)
# video 1/1 (428/899) /content/yolov5/../traffic.mp4: 384x640 8 Cars, Done. (0.009s)
# video 1/1 (429/899) /content/yolov5/../traffic.mp4: 384x640 8 Cars, Done. (0.009s)
# video 1/1 (430/899) /content/yolov5/../traffic.mp4: 384x640 8 Cars, Done. (0.009s)
# video 1/1 (431/899) /content/yolov5/../traffic.mp4: 384x640 8 Cars, Done. (0.009s)
# video 1/1 (432/899) /content/yolov5/../traffic.mp4: 384x640 7 Cars, Done. (0.009s)
# video 1/1 (433/899) /content/yolov5/../traffic.mp4: 384x640 7 Cars, Done. (0.009s)
# video 1/1 (434/899) /content/yolov5/../traffic.mp4: 384x640 7 Cars, Done. (0.009s)
# video 1/1 (435/899) /content/yolov5/../traffic.mp4: 384x640 7 Cars, Done. (0.009s)
# video 1/1 (436/899) /content/yolov5/../traffic.mp4: 384x640 7 Cars, Done. (0.009s)
# video 1/1 (437/899) /content/yolov5/../traffic.mp4: 384x640 7 Cars, Done. (0.009s)
# video 1/1 (438/899) /content/yolov5/../traffic.mp4: 384x640 7 Cars, Done. (0.009s)
# video 1/1 (439/899) /content/yolov5/../traffic.mp4: 384x640 7 Cars, Done. (0.009s)
# video 1/1 (440/899) /content/yolov5/../traffic.mp4: 384x640 7 Cars, Done. (0.009s)
# video 1/1 (441/899) /content/yolov5/../traffic.mp4: 384x640 7 Cars, Done. (0.009s)
# video 1/1 (442/899) /content/yolov5/../traffic.mp4: 384x640 6 Cars, Done. (0.009s)
# video 1/1 (443/899) /content/yolov5/../traffic.mp4: 384x640 6 Cars, Done. (0.009s)
# video 1/1 (444/899) /content/yolov5/../traffic.mp4: 384x640 5 Cars, Done. (0.009s)
# video 1/1 (445/899) /content/yolov5/../traffic.mp4: 384x640 5 Cars, Done. (0.009s)
# video 1/1 (446/899) /content/yolov5/../traffic.mp4: 384x640 5 Cars, Done. (0.009s)
# video 1/1 (447/899) /content/yolov5/../traffic.mp4: 384x640 1 Ambulance, 4 Cars, Done. (0.009s)
# video 1/1 (448/899) /content/yolov5/../traffic.mp4: 384x640 4 Cars, Done. (0.009s)
# video 1/1 (449/899) /content/yolov5/../traffic.mp4: 384x640 4 Cars, Done. (0.009s)
# video 1/1 (450/899) /content/yolov5/../traffic.mp4: 384x640 1 Ambulance, 4 Cars, Done. (0.009s)
# video 1/1 (451/899) /content/yolov5/../traffic.mp4: 384x640 1 Ambulance, 4 Cars, Done. (0.009s)
# video 1/1 (452/899) /content/yolov5/../traffic.mp4: 384x640 1 Ambulance, 3 Cars, Done. (0.009s)
# video 1/1 (453/899) /content/yolov5/../traffic.mp4: 384x640 5 Cars, Done. (0.009s)
# video 1/1 (454/899) /content/yolov5/../traffic.mp4: 384x640 1 Ambulance, 5 Cars, Done. (0.009s)
# video 1/1 (455/899) /content/yolov5/../traffic.mp4: 384x640 5 Cars, Done. (0.009s)
# video 1/1 (456/899) /content/yolov5/../traffic.mp4: 384x640 5 Cars, Done. (0.009s)
# video 1/1 (457/899) /content/yolov5/../traffic.mp4: 384x640 5 Cars, Done. (0.009s)
# video 1/1 (458/899) /content/yolov5/../traffic.mp4: 384x640 4 Cars, Done. (0.009s)
# video 1/1 (459/899) /content/yolov5/../traffic.mp4: 384x640 4 Cars, Done. (0.009s)
# video 1/1 (460/899) /content/yolov5/../traffic.mp4: 384x640 6 Cars, Done. (0.009s)
# video 1/1 (461/899) /content/yolov5/../traffic.mp4: 384x640 6 Cars, Done. (0.009s)
# video 1/1 (462/899) /content/yolov5/../traffic.mp4: 384x640 5 Cars, Done. (0.009s)
# video 1/1 (463/899) /content/yolov5/../traffic.mp4: 384x640 5 Cars, Done. (0.009s)
# video 1/1 (464/899) /content/yolov5/../traffic.mp4: 384x640 1 Ambulance, 4 Cars, Done. (0.009s)
# video 1/1 (465/899) /content/yolov5/../traffic.mp4: 384x640 5 Cars, Done. (0.009s)
# video 1/1 (466/899) /content/yolov5/../traffic.mp4: 384x640 6 Cars, Done. (0.009s)
# video 1/1 (467/899) /content/yolov5/../traffic.mp4: 384x640 5 Cars, Done. (0.009s)
# video 1/1 (468/899) /content/yolov5/../traffic.mp4: 384x640 6 Cars, Done. (0.010s)
# video 1/1 (469/899) /content/yolov5/../traffic.mp4: 384x640 6 Cars, Done. (0.009s)
# video 1/1 (470/899) /content/yolov5/../traffic.mp4: 384x640 6 Cars, Done. (0.009s)
# video 1/1 (471/899) /content/yolov5/../traffic.mp4: 384x640 7 Cars, Done. (0.009s)
# video 1/1 (472/899) /content/yolov5/../traffic.mp4: 384x640 7 Cars, Done. (0.009s)
# video 1/1 (473/899) /content/yolov5/../traffic.mp4: 384x640 7 Cars, Done. (0.009s)
# video 1/1 (474/899) /content/yolov5/../traffic.mp4: 384x640 7 Cars, Done. (0.009s)
# video 1/1 (475/899) /content/yolov5/../traffic.mp4: 384x640 8 Cars, Done. (0.009s)
# video 1/1 (476/899) /content/yolov5/../traffic.mp4: 384x640 8 Cars, Done. (0.009s)
# video 1/1 (477/899) /content/yolov5/../traffic.mp4: 384x640 8 Cars, Done. (0.009s)
# video 1/1 (478/899) /content/yolov5/../traffic.mp4: 384x640 7 Cars, 2 Trucks, Done. (0.009s)
# video 1/1 (479/899) /content/yolov5/../traffic.mp4: 384x640 8 Cars, Done. (0.010s)
# video 1/1 (480/899) /content/yolov5/../traffic.mp4: 384x640 8 Cars, 2 Trucks, Done. (0.009s)
# video 1/1 (481/899) /content/yolov5/../traffic.mp4: 384x640 8 Cars, 2 Trucks, Done. (0.009s)
# video 1/1 (482/899) /content/yolov5/../traffic.mp4: 384x640 7 Cars, Done. (0.010s)
# video 1/1 (483/899) /content/yolov5/../traffic.mp4: 384x640 8 Cars, Done. (0.009s)
# video 1/1 (484/899) /content/yolov5/../traffic.mp4: 384x640 7 Cars, Done. (0.009s)
# video 1/1 (485/899) /content/yolov5/../traffic.mp4: 384x640 8 Cars, Done. (0.009s)
# video 1/1 (486/899) /content/yolov5/../traffic.mp4: 384x640 8 Cars, Done. (0.009s)
# video 1/1 (487/899) /content/yolov5/../traffic.mp4: 384x640 8 Cars, Done. (0.009s)
# video 1/1 (488/899) /content/yolov5/../traffic.mp4: 384x640 8 Cars, Done. (0.009s)
# video 1/1 (489/899) /content/yolov5/../traffic.mp4: 384x640 7 Cars, Done. (0.009s)
# video 1/1 (490/899) /content/yolov5/../traffic.mp4: 384x640 7 Cars, Done. (0.009s)
# video 1/1 (491/899) /content/yolov5/../traffic.mp4: 384x640 8 Cars, Done. (0.009s)
# video 1/1 (492/899) /content/yolov5/../traffic.mp4: 384x640 7 Cars, Done. (0.009s)
# video 1/1 (493/899) /content/yolov5/../traffic.mp4: 384x640 7 Cars, Done. (0.009s)
# video 1/1 (494/899) /content/yolov5/../traffic.mp4: 384x640 8 Cars, Done. (0.009s)
# video 1/1 (495/899) /content/yolov5/../traffic.mp4: 384x640 6 Cars, Done. (0.009s)
# video 1/1 (496/899) /content/yolov5/../traffic.mp4: 384x640 6 Cars, Done. (0.009s)
# video 1/1 (497/899) /content/yolov5/../traffic.mp4: 384x640 8 Cars, Done. (0.009s)
# video 1/1 (498/899) /content/yolov5/../traffic.mp4: 384x640 8 Cars, Done. (0.009s)
# video 1/1 (499/899) /content/yolov5/../traffic.mp4: 384x640 8 Cars, Done. (0.009s)
# video 1/1 (500/899) /content/yolov5/../traffic.mp4: 384x640 7 Cars, Done. (0.009s)
# video 1/1 (501/899) /content/yolov5/../traffic.mp4: 384x640 7 Cars, Done. (0.009s)
# video 1/1 (502/899) /content/yolov5/../traffic.mp4: 384x640 7 Cars, Done. (0.009s)
# video 1/1 (503/899) /content/yolov5/../traffic.mp4: 384x640 7 Cars, Done. (0.009s)
# video 1/1 (504/899) /content/yolov5/../traffic.mp4: 384x640 7 Cars, Done. (0.009s)
# video 1/1 (505/899) /content/yolov5/../traffic.mp4: 384x640 7 Cars, Done. (0.009s)
# video 1/1 (506/899) /content/yolov5/../traffic.mp4: 384x640 7 Cars, Done. (0.009s)
# video 1/1 (507/899) /content/yolov5/../traffic.mp4: 384x640 7 Cars, Done. (0.009s)
# video 1/1 (508/899) /content/yolov5/../traffic.mp4: 384x640 8 Cars, Done. (0.009s)
# video 1/1 (509/899) /content/yolov5/../traffic.mp4: 384x640 8 Cars, Done. (0.009s)
# video 1/1 (510/899) /content/yolov5/../traffic.mp4: 384x640 8 Cars, Done. (0.009s)
# video 1/1 (511/899) /content/yolov5/../traffic.mp4: 384x640 8 Cars, Done. (0.009s)
# video 1/1 (512/899) /content/yolov5/../traffic.mp4: 384x640 8 Cars, Done. (0.010s)
# video 1/1 (513/899) /content/yolov5/../traffic.mp4: 384x640 8 Cars, Done. (0.009s)
# video 1/1 (514/899) /content/yolov5/../traffic.mp4: 384x640 8 Cars, Done. (0.009s)
# video 1/1 (515/899) /content/yolov5/../traffic.mp4: 384x640 8 Cars, Done. (0.009s)
# video 1/1 (516/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (517/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (518/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (519/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (520/899) /content/yolov5/../traffic.mp4: 384x640 8 Cars, Done. (0.009s)
# video 1/1 (521/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (522/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (523/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (524/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (525/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.009s)
# video 1/1 (526/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (527/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.009s)
# video 1/1 (528/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.009s)
# video 1/1 (529/899) /content/yolov5/../traffic.mp4: 384x640 12 Cars, Done. (0.009s)
# video 1/1 (530/899) /content/yolov5/../traffic.mp4: 384x640 12 Cars, Done. (0.009s)
# video 1/1 (531/899) /content/yolov5/../traffic.mp4: 384x640 12 Cars, Done. (0.009s)
# video 1/1 (532/899) /content/yolov5/../traffic.mp4: 384x640 12 Cars, Done. (0.009s)
# video 1/1 (533/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (534/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.009s)
# video 1/1 (535/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.009s)
# video 1/1 (536/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.009s)
# video 1/1 (537/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (538/899) /content/yolov5/../traffic.mp4: 384x640 11 Cars, Done. (0.009s)
# video 1/1 (539/899) /content/yolov5/../traffic.mp4: 384x640 11 Cars, Done. (0.009s)
# video 1/1 (540/899) /content/yolov5/../traffic.mp4: 384x640 11 Cars, Done. (0.009s)
# video 1/1 (541/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.009s)
# video 1/1 (542/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.009s)
# video 1/1 (543/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.009s)
# video 1/1 (544/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (545/899) /content/yolov5/../traffic.mp4: 384x640 8 Cars, Done. (0.009s)
# video 1/1 (546/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (547/899) /content/yolov5/../traffic.mp4: 384x640 8 Cars, Done. (0.009s)
# video 1/1 (548/899) /content/yolov5/../traffic.mp4: 384x640 8 Cars, Done. (0.009s)
# video 1/1 (549/899) /content/yolov5/../traffic.mp4: 384x640 8 Cars, Done. (0.009s)
# video 1/1 (550/899) /content/yolov5/../traffic.mp4: 384x640 8 Cars, Done. (0.009s)
# video 1/1 (551/899) /content/yolov5/../traffic.mp4: 384x640 8 Cars, Done. (0.009s)
# video 1/1 (552/899) /content/yolov5/../traffic.mp4: 384x640 8 Cars, Done. (0.009s)
# video 1/1 (553/899) /content/yolov5/../traffic.mp4: 384x640 8 Cars, Done. (0.009s)
# video 1/1 (554/899) /content/yolov5/../traffic.mp4: 384x640 8 Cars, Done. (0.009s)
# video 1/1 (555/899) /content/yolov5/../traffic.mp4: 384x640 7 Cars, Done. (0.009s)
# video 1/1 (556/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (557/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (558/899) /content/yolov5/../traffic.mp4: 384x640 8 Cars, Done. (0.009s)
# video 1/1 (559/899) /content/yolov5/../traffic.mp4: 384x640 8 Cars, Done. (0.009s)
# video 1/1 (560/899) /content/yolov5/../traffic.mp4: 384x640 8 Cars, Done. (0.009s)
# video 1/1 (561/899) /content/yolov5/../traffic.mp4: 384x640 8 Cars, Done. (0.009s)
# video 1/1 (562/899) /content/yolov5/../traffic.mp4: 384x640 8 Cars, Done. (0.009s)
# video 1/1 (563/899) /content/yolov5/../traffic.mp4: 384x640 8 Cars, Done. (0.009s)
# ...
# video 1/1 (710/899) /content/yolov5/../traffic.mp4: 384x640 11 Cars, Done. (0.009s)
# video 1/1 (711/899) /content/yolov5/../traffic.mp4: 384x640 11 Cars, Done. (0.009s)
# video 1/1 (712/899) /content/yolov5/../traffic.mp4: 384x640 12 Cars, Done. (0.009s)
# video 1/1 (713/899) /content/yolov5/../traffic.mp4: 384x640 11 Cars, Done. (0.009s)
# video 1/1 (714/899) /content/yolov5/../traffic.mp4: 384x640 11 Cars, Done. (0.009s)
# video 1/1 (715/899) /content/yolov5/../traffic.mp4: 384x640 11 Cars, Done. (0.009s)
# video 1/1 (716/899) /content/yolov5/../traffic.mp4: 384x640 11 Cars, Done. (0.009s)
# video 1/1 (717/899) /content/yolov5/../traffic.mp4: 384x640 11 Cars, Done. (0.009s)
# video 1/1 (718/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.009s)
# video 1/1 (719/899) /content/yolov5/../traffic.mp4: 384x640 11 Cars, Done. (0.009s)
# video 1/1 (720/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.009s)
# video 1/1 (721/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.009s)
# video 1/1 (722/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.009s)
# video 1/1 (723/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.009s)
# video 1/1 (724/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.009s)
# video 1/1 (725/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (726/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (727/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (728/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.009s)
# video 1/1 (729/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.009s)
# video 1/1 (730/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.009s)
# video 1/1 (731/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (732/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.009s)
# video 1/1 (733/899) /content/yolov5/../traffic.mp4: 384x640 11 Cars, Done. (0.009s)
# video 1/1 (734/899) /content/yolov5/../traffic.mp4: 384x640 11 Cars, Done. (0.009s)
# video 1/1 (735/899) /content/yolov5/../traffic.mp4: 384x640 11 Cars, Done. (0.009s)
# video 1/1 (736/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.009s)
# video 1/1 (737/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (738/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (739/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (740/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (741/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (742/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (743/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.009s)
# video 1/1 (744/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.009s)
# video 1/1 (745/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (746/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (747/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (748/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (749/899) /content/yolov5/../traffic.mp4: 384x640 8 Cars, Done. (0.009s)
# video 1/1 (750/899) /content/yolov5/../traffic.mp4: 384x640 8 Cars, Done. (0.009s)
# video 1/1 (751/899) /content/yolov5/../traffic.mp4: 384x640 8 Cars, Done. (0.009s)
# video 1/1 (752/899) /content/yolov5/../traffic.mp4: 384x640 8 Cars, Done. (0.009s)
# video 1/1 (753/899) /content/yolov5/../traffic.mp4: 384x640 8 Cars, Done. (0.009s)
# video 1/1 (754/899) /content/yolov5/../traffic.mp4: 384x640 6 Cars, Done. (0.009s)
# video 1/1 (755/899) /content/yolov5/../traffic.mp4: 384x640 6 Cars, Done. (0.009s)
# video 1/1 (756/899) /content/yolov5/../traffic.mp4: 384x640 1 Ambulance, 7 Cars, Done. (0.009s)
# video 1/1 (757/899) /content/yolov5/../traffic.mp4: 384x640 7 Cars, Done. (0.009s)
# video 1/1 (758/899) /content/yolov5/../traffic.mp4: 384x640 8 Cars, Done. (0.009s)
# video 1/1 (759/899) /content/yolov5/../traffic.mp4: 384x640 8 Cars, Done. (0.009s)
# video 1/1 (760/899) /content/yolov5/../traffic.mp4: 384x640 1 Ambulance, 7 Cars, Done. (0.009s)
# video 1/1 (761/899) /content/yolov5/../traffic.mp4: 384x640 7 Cars, Done. (0.009s)
# video 1/1 (762/899) /content/yolov5/../traffic.mp4: 384x640 6 Cars, Done. (0.010s)
# video 1/1 (763/899) /content/yolov5/../traffic.mp4: 384x640 6 Cars, Done. (0.009s)
# video 1/1 (764/899) /content/yolov5/../traffic.mp4: 384x640 6 Cars, Done. (0.009s)
# video 1/1 (765/899) /content/yolov5/../traffic.mp4: 384x640 6 Cars, Done. (0.009s)
# video 1/1 (766/899) /content/yolov5/../traffic.mp4: 384x640 6 Cars, Done. (0.009s)
# video 1/1 (767/899) /content/yolov5/../traffic.mp4: 384x640 6 Cars, Done. (0.009s)
# video 1/1 (768/899) /content/yolov5/../traffic.mp4: 384x640 6 Cars, Done. (0.009s)
# video 1/1 (769/899) /content/yolov5/../traffic.mp4: 384x640 6 Cars, Done. (0.009s)
# video 1/1 (770/899) /content/yolov5/../traffic.mp4: 384x640 1 Ambulance, 6 Cars, Done. (0.009s)
# video 1/1 (771/899) /content/yolov5/../traffic.mp4: 384x640 1 Ambulance, 6 Cars, Done. (0.010s)
# video 1/1 (772/899) /content/yolov5/../traffic.mp4: 384x640 1 Ambulance, 6 Cars, Done. (0.009s)
# video 1/1 (773/899) /content/yolov5/../traffic.mp4: 384x640 6 Cars, Done. (0.010s)
# video 1/1 (774/899) /content/yolov5/../traffic.mp4: 384x640 6 Cars, Done. (0.009s)
# video 1/1 (775/899) /content/yolov5/../traffic.mp4: 384x640 6 Cars, Done. (0.009s)
# video 1/1 (776/899) /content/yolov5/../traffic.mp4: 384x640 7 Cars, Done. (0.009s)
# video 1/1 (777/899) /content/yolov5/../traffic.mp4: 384x640 7 Cars, Done. (0.009s)
# video 1/1 (778/899) /content/yolov5/../traffic.mp4: 384x640 6 Cars, Done. (0.009s)
# video 1/1 (779/899) /content/yolov5/../traffic.mp4: 384x640 6 Cars, Done. (0.009s)
# video 1/1 (780/899) /content/yolov5/../traffic.mp4: 384x640 6 Cars, Done. (0.009s)
# video 1/1 (781/899) /content/yolov5/../traffic.mp4: 384x640 1 Ambulance, 5 Cars, Done. (0.009s)
# video 1/1 (782/899) /content/yolov5/../traffic.mp4: 384x640 1 Ambulance, 5 Cars, Done. (0.009s)
# video 1/1 (783/899) /content/yolov5/../traffic.mp4: 384x640 1 Ambulance, 5 Cars, Done. (0.010s)
# video 1/1 (784/899) /content/yolov5/../traffic.mp4: 384x640 5 Cars, Done. (0.009s)
# video 1/1 (785/899) /content/yolov5/../traffic.mp4: 384x640 6 Cars, Done. (0.009s)
# video 1/1 (786/899) /content/yolov5/../traffic.mp4: 384x640 7 Cars, Done. (0.009s)
# video 1/1 (787/899) /content/yolov5/../traffic.mp4: 384x640 6 Cars, Done. (0.009s)
# video 1/1 (788/899) /content/yolov5/../traffic.mp4: 384x640 6 Cars, Done. (0.009s)
# video 1/1 (789/899) /content/yolov5/../traffic.mp4: 384x640 6 Cars, Done. (0.009s)
# video 1/1 (790/899) /content/yolov5/../traffic.mp4: 384x640 6 Cars, Done. (0.009s)
# video 1/1 (791/899) /content/yolov5/../traffic.mp4: 384x640 6 Cars, Done. (0.009s)
# video 1/1 (792/899) /content/yolov5/../traffic.mp4: 384x640 7 Cars, Done. (0.011s)
# video 1/1 (793/899) /content/yolov5/../traffic.mp4: 384x640 7 Cars, Done. (0.009s)
# video 1/1 (794/899) /content/yolov5/../traffic.mp4: 384x640 7 Cars, Done. (0.009s)
# video 1/1 (795/899) /content/yolov5/../traffic.mp4: 384x640 7 Cars, Done. (0.009s)
# video 1/1 (796/899) /content/yolov5/../traffic.mp4: 384x640 7 Cars, Done. (0.009s)
# video 1/1 (797/899) /content/yolov5/../traffic.mp4: 384x640 8 Cars, Done. (0.009s)
# video 1/1 (798/899) /content/yolov5/../traffic.mp4: 384x640 8 Cars, Done. (0.009s)
# video 1/1 (799/899) /content/yolov5/../traffic.mp4: 384x640 8 Cars, Done. (0.009s)
# video 1/1 (800/899) /content/yolov5/../traffic.mp4: 384x640 7 Cars, Done. (0.009s)
# video 1/1 (801/899) /content/yolov5/../traffic.mp4: 384x640 7 Cars, Done. (0.009s)
# video 1/1 (802/899) /content/yolov5/../traffic.mp4: 384x640 7 Cars, Done. (0.010s)
# video 1/1 (803/899) /content/yolov5/../traffic.mp4: 384x640 8 Cars, Done. (0.009s)
# video 1/1 (804/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.011s)
# video 1/1 (805/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.010s)
# video 1/1 (806/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (807/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.010s)
# video 1/1 (808/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.010s)
# video 1/1 (809/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, 1 Truck, Done. (0.010s)
# video 1/1 (810/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, 1 Truck, Done. (0.009s)
# video 1/1 (811/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.010s)
# video 1/1 (812/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.010s)
# video 1/1 (813/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.009s)
# video 1/1 (814/899) /content/yolov5/../traffic.mp4: 384x640 8 Cars, Done. (0.010s)
# video 1/1 (815/899) /content/yolov5/../traffic.mp4: 384x640 8 Cars, Done. (0.009s)
# video 1/1 (816/899) /content/yolov5/../traffic.mp4: 384x640 8 Cars, Done. (0.009s)
# video 1/1 (817/899) /content/yolov5/../traffic.mp4: 384x640 8 Cars, Done. (0.009s)
# video 1/1 (818/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (819/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (820/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (821/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (822/899) /content/yolov5/../traffic.mp4: 384x640 8 Cars, Done. (0.009s)
# video 1/1 (823/899) /content/yolov5/../traffic.mp4: 384x640 8 Cars, Done. (0.009s)
# video 1/1 (824/899) /content/yolov5/../traffic.mp4: 384x640 8 Cars, Done. (0.009s)
# video 1/1 (825/899) /content/yolov5/../traffic.mp4: 384x640 8 Cars, Done. (0.009s)
# video 1/1 (826/899) /content/yolov5/../traffic.mp4: 384x640 8 Cars, Done. (0.009s)
# video 1/1 (827/899) /content/yolov5/../traffic.mp4: 384x640 8 Cars, Done. (0.009s)
# video 1/1 (828/899) /content/yolov5/../traffic.mp4: 384x640 8 Cars, Done. (0.009s)
# video 1/1 (829/899) /content/yolov5/../traffic.mp4: 384x640 8 Cars, Done. (0.009s)
# video 1/1 (830/899) /content/yolov5/../traffic.mp4: 384x640 7 Cars, Done. (0.009s)
# video 1/1 (831/899) /content/yolov5/../traffic.mp4: 384x640 7 Cars, Done. (0.010s)
# video 1/1 (832/899) /content/yolov5/../traffic.mp4: 384x640 7 Cars, Done. (0.009s)
# video 1/1 (833/899) /content/yolov5/../traffic.mp4: 384x640 7 Cars, Done. (0.009s)
# video 1/1 (834/899) /content/yolov5/../traffic.mp4: 384x640 7 Cars, Done. (0.009s)
# video 1/1 (835/899) /content/yolov5/../traffic.mp4: 384x640 7 Cars, Done. (0.009s)
# video 1/1 (836/899) /content/yolov5/../traffic.mp4: 384x640 8 Cars, Done. (0.009s)
# video 1/1 (837/899) /content/yolov5/../traffic.mp4: 384x640 8 Cars, Done. (0.009s)
# video 1/1 (838/899) /content/yolov5/../traffic.mp4: 384x640 8 Cars, Done. (0.009s)
# video 1/1 (839/899) /content/yolov5/../traffic.mp4: 384x640 8 Cars, Done. (0.009s)
# video 1/1 (840/899) /content/yolov5/../traffic.mp4: 384x640 8 Cars, Done. (0.009s)
# video 1/1 (841/899) /content/yolov5/../traffic.mp4: 384x640 8 Cars, Done. (0.009s)
# video 1/1 (842/899) /content/yolov5/../traffic.mp4: 384x640 8 Cars, Done. (0.010s)
# video 1/1 (843/899) /content/yolov5/../traffic.mp4: 384x640 8 Cars, Done. (0.009s)
# video 1/1 (844/899) /content/yolov5/../traffic.mp4: 384x640 7 Cars, Done. (0.009s)
# video 1/1 (845/899) /content/yolov5/../traffic.mp4: 384x640 7 Cars, Done. (0.009s)
# video 1/1 (846/899) /content/yolov5/../traffic.mp4: 384x640 7 Cars, Done. (0.009s)
# video 1/1 (847/899) /content/yolov5/../traffic.mp4: 384x640 7 Cars, Done. (0.009s)
# video 1/1 (848/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (849/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (850/899) /content/yolov5/../traffic.mp4: 384x640 8 Cars, Done. (0.009s)
# video 1/1 (851/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (852/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (853/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (854/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (855/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.010s)
# video 1/1 (856/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (857/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (858/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (859/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.010s)
# video 1/1 (860/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (861/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (862/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (863/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (864/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.010s)
# video 1/1 (865/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (866/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (867/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (868/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (869/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (870/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (871/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (872/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (873/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (874/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (875/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (876/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (877/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (878/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (879/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (880/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (881/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (882/899) /content/yolov5/../traffic.mp4: 384x640 8 Cars, Done. (0.009s)
# video 1/1 (883/899) /content/yolov5/../traffic.mp4: 384x640 8 Cars, Done. (0.010s)
# video 1/1 (884/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (885/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (886/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.010s)
# video 1/1 (887/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (888/899) /content/yolov5/../traffic.mp4: 384x640 8 Cars, Done. (0.009s)
# video 1/1 (889/899) /content/yolov5/../traffic.mp4: 384x640 8 Cars, Done. (0.009s)
# video 1/1 (890/899) /content/yolov5/../traffic.mp4: 384x640 8 Cars, Done. (0.009s)
# video 1/1 (891/899) /content/yolov5/../traffic.mp4: 384x640 8 Cars, Done. (0.009s)
# video 1/1 (892/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (893/899) /content/yolov5/../traffic.mp4: 384x640 8 Cars, Done. (0.009s)
# video 1/1 (894/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (895/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (896/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (897/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (898/899) /content/yolov5/../traffic.mp4: 384x640 9 Cars, Done. (0.009s)
# video 1/1 (899/899) /content/yolov5/../traffic.mp4: 384x640 10 Cars, Done. (0.009s)
# Results saved to runs/detect/exp10
# Done. (20.887s)

# %% [markdown]
# # 2. Test
# Test a model's accuracy on [COCO](https://cocodataset.org/#home) val or test-dev datasets. Models are downloaded automatically from the [latest YOLOv5 release](https://github.com/ultralytics/yolov5/releases). To show results by class use the `--verbose` flag. Note that `pycocotools` metrics may be ~1% better than the equivalent repo metrics, as is visible below, due to slight differences in mAP computation.

# %% [markdown]
# ## COCO val2017
# Download [COCO val 2017](https://github.com/ultralytics/yolov5/blob/74b34872fdf41941cddcf243951cdb090fbac17b/data/coco.yaml#L14) dataset (1GB - 5000 images), and test model accuracy.

# %%
# Download COCO val2017
torch.hub.download_url_to_file('https://github.com/ultralytics/yolov5/releases/download/v1.0/coco2017val.zip', 'tmp.zip')
# !unzip -q tmp.zip -d ../datasets && rm tmp.zip
# Out:
# HBox(children=(FloatProgress(value=0.0, max=819257867.0), HTML(value='')))

# %%
# Run YOLOv5x on COCO val2017
# !python test.py --weights yolov5x.pt --data coco.yaml --img 640 --iou 0.65 --half
# Out:
# Namespace(augment=False, batch_size=32, conf_thres=0.001, data='./data/coco.yaml', device='', exist_ok=False, half=True, img_size=640, iou_thres=0.65, name='exp', project='runs/test', save_conf=False, save_hybrid=False, save_json=True, save_txt=False, single_cls=False, task='val', verbose=False, weights=['yolov5x.pt'])
# YOLOv5 🚀 v5.0-157-gc6b51f4 torch 1.8.1+cu101 CUDA:0 (Tesla V100-SXM2-16GB, 16160.5MB)
#
# Downloading https://github.com/ultralytics/yolov5/releases/download/v5.0/yolov5x.pt to yolov5x.pt...
# 100% 168M/168M [00:01<00:00, 156MB/s]
#
# Fusing layers...
# Model Summary: 476 layers, 87730285 parameters, 0 gradients
# val: Scanning '../coco/val2017' images and labels...4952 found, 48 missing, 0 empty, 0 corrupted: 100% 5000/5000 [00:01<00:00, 3008.87it/s]
# val: New cache created: ../coco/val2017.cache
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 157/157 [01:17<00:00,  2.02it/s]
#                  all       5000      36335      0.746      0.626       0.68       0.49
# Speed: 5.3/1.5/6.8 ms inference/NMS/total per 640x640 image at batch-size 32
#
# Evaluating pycocotools mAP... saving runs/test/exp/yolov5x_predictions.json...
# loading annotations into memory...
# Done (t=0.44s)
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=4.88s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=83.47s).
# Accumulating evaluation results...
# DONE (t=12.96s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.504
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.688
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.546
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.351
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.551
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.644
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.382
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.629
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.681
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.524
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.735
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.827
# Results saved to runs/test/exp

# %% [markdown]
# ## COCO test-dev2017
# Download [COCO test2017](https://github.com/ultralytics/yolov5/blob/74b34872fdf41941cddcf243951cdb090fbac17b/data/coco.yaml#L15) dataset (7GB - 40,000 images), to test model accuracy on test-dev set (**20,000 images, no labels**). Results are saved to a `*.json` file which should be **zipped** and submitted to the evaluation server at https://competitions.codalab.org/competitions/20794.

# %%
# Download COCO test-dev2017
torch.hub.download_url_to_file('https://github.com/ultralytics/yolov5/releases/download/v1.0/coco2017labels.zip', 'tmp.zip')
# !unzip -q tmp.zip -d ../ && rm tmp.zip # unzip labels
# !f="test2017.zip" && curl http://images.cocodataset.org/zips/$f -o $f && unzip -q $f && rm $f  # 7GB,  41k images
# %mv ./test2017 ../coco/images  # move to /coco

# %%
# Run YOLOv5s on COCO test-dev2017 using --task test
# !python test.py --weights yolov5s.pt --data coco.yaml --task test

# %% [markdown]
# # 3. Train
#
# Download [COCO128](https://www.kaggle.com/ultralytics/coco128), a small 128-image tutorial dataset, start tensorboard and train YOLOv5s from a pretrained checkpoint for 3 epochs (note actual training is typically much longer, around **300-1000 epochs**, depending on your dataset).

# %%
# Download COCO128
torch.hub.download_url_to_file('https://github.com/ultralytics/yolov5/releases/download/v1.0/coco128.zip', 'tmp.zip')
# !unzip -q tmp.zip -d ../ && rm tmp.zip
# Out:
# HBox(children=(FloatProgress(value=0.0, max=22091032.0), HTML(value='')))

# %% [markdown]
# Train a YOLOv5s model on [COCO128](https://www.kaggle.com/ultralytics/coco128) with `--data coco128.yaml`, starting from pretrained `--weights yolov5s.pt`, or from randomly initialized `--weights '' --cfg yolov5s.yaml`. Models are downloaded automatically from the [latest YOLOv5 release](https://github.com/ultralytics/yolov5/releases), and **COCO, COCO128, and VOC datasets are downloaded automatically** on first use.
#
# All training results are saved to `runs/train/` with incrementing run directories, i.e. `runs/train/exp2`, `runs/train/exp3` etc.

# %%
# Tensorboard  (optional)
# %load_ext tensorboard
# %tensorboard --logdir runs/train

# %%
# Weights & Biases  (optional)
# %pip install -q wandb
import wandb
wandb.login()

# %%
# Train YOLOv5s on COCO128 for 3 epochs
# !python train.py --img 640 --batch 2 --epochs 60 --data custom_data.yaml --weights yolov5s.pt --cache
# Out:
# train: weights=yolov5s.pt, cfg=, data=custom_data.yaml, hyp=data/hyps/hyp.scratch.yaml, epochs=60, batch_size=2, img_size=[640], rect=False, resume=False, nosave=False, notest=False, noautoanchor=False, evolve=None, bucket=, cache_images=True, image_weights=False, device=, multi_scale=False, single_cls=False, adam=False, sync_bn=False, workers=8, project=runs/train, entity=None, name=exp, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, upload_dataset=False, bbox_interval=-1, save_period=-1, artifact_alias=latest, local_rank=-1
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v5.0-276-gdabad57 torch 1.9.0+cu102 CUDA:0 (Tesla T4, 15109.75MB)
#
# hyperparameters: lr0=0.01, lrf=0.2, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# tensorboard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# 2021-07-09 08:05:49.662094: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# wandb: Install Weights & Biases for YOLOv5 logging with 'pip install wandb' (recommended)
# Overriding model.yaml nc=80 with nc=5
#
#                  from  n    params  module                                  arguments
#   0                -1  1      3520  models.common.Focus                     [3, 32, 3]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     18816  models.common.C3                        [64, 64, 1]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  1    156928  models.common.C3                        [128, 128, 3]
#   5                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   6                -1  1    625152  models.common.C3                        [256, 256, 3]
#   7                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   8                -1  1    656896  models.common.SPP                       [512, 512, [5, 9, 13]]
#   9                -1  1   1182720  models.common.C3                        [512, 512, 1, False]
#  10                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1    361984  models.common.C3                        [512, 256, 1, False]
#  14                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1     90880  models.common.C3                        [256, 128, 1, False]
#  18                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1    296448  models.common.C3                        [256, 256, 1, False]
#  21                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1   1182720  models.common.C3                        [512, 512, 1, False]
#  24      [17, 20, 23]  1     26970  models.yolo.Detect                      [5, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [128, 256, 512]]
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# Model Summary: 283 layers, 7074330 parameters, 7074330 gradients, 16.4 GFLOPs
#
# Transferred 356/362 items from yolov5s.pt
# Scaled weight_decay = 0.0005
# Optimizer groups: 62 .bias, 62 conv.weight, 59 other
# albumentations: version 1.0.0 required by YOLOv5, but version 0.1.12 is currently installed
# train: Scanning '../train_data/labels/train' images and labels...878 found, 0 missing, 0 empty, 0 corrupted: 100% 878/878 [00:00<00:00, 2863.66it/s]
# train: New cache created: ../train_data/labels/train.cache
# train: Caching images (1.1GB): 100% 878/878 [00:02<00:00, 293.48it/s]
# val: Scanning '../train_data/labels/val' images and labels...250 found, 0 missing, 0 empty, 0 corrupted: 100% 250/250 [00:00<00:00, 2129.17it/s]
# val: New cache created: ../train_data/labels/val.cache
# val: Caching images (0.3GB): 100% 250/250 [00:00<00:00, 292.30it/s]
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# Plotting labels...
#
# autoanchor: Analyzing anchors... anchors/target = 3.82, Best Possible Recall (BPR) = 1.0000
# Image sizes 640 train, 640 test
# Using 2 dataloader workers
# Logging results to runs/train/exp6
# Starting training for 60 epochs...
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#       0/59    0.514G   0.07956   0.03288   0.03989    0.1523        12       640: 100% 439/439 [00:30<00:00, 14.28it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 63/63 [00:02<00:00, 26.06it/s]
#                  all        250        454      0.196      0.288      0.184     0.0944
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#       1/59    0.587G   0.05184   0.02904    0.0315    0.1124         7       640: 100% 439/439 [00:27<00:00, 16.24it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 63/63 [00:02<00:00, 27.17it/s]
#                  all        250        454      0.228      0.415      0.227     0.0967
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#       2/59    0.587G   0.05264   0.02593   0.02809    0.1067         3       640: 100% 439/439 [00:27<00:00, 16.22it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 63/63 [00:02<00:00, 27.88it/s]
#                  all        250        454      0.186      0.354      0.186     0.0721
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#       3/59    0.587G   0.04907   0.02667   0.02587    0.1016         7       640: 100% 439/439 [00:27<00:00, 16.22it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 63/63 [00:02<00:00, 27.62it/s]
#                  all        250        454      0.258      0.485      0.325      0.156
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#       4/59    0.587G   0.04221   0.02591   0.02375   0.09187         7       640: 100% 439/439 [00:27<00:00, 16.10it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 63/63 [00:02<00:00, 27.95it/s]
#                  all        250        454      0.244      0.522      0.279      0.134
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#       5/59    0.587G    0.0417   0.02676    0.0245   0.09296         2       640: 100% 439/439 [00:27<00:00, 16.21it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 63/63 [00:02<00:00, 27.80it/s]
#                  all        250        454      0.328      0.492      0.313      0.134
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#       6/59    0.587G   0.04045   0.02691   0.02356   0.09093         6       640: 100% 439/439 [00:27<00:00, 16.12it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 63/63 [00:02<00:00, 27.85it/s]
#                  all        250        454      0.276      0.472      0.299      0.159
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#       7/59    0.587G   0.03944   0.02734   0.02248   0.08926         4       640: 100% 439/439 [00:27<00:00, 16.09it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 63/63 [00:02<00:00, 27.86it/s]
#                  all        250        454      0.338       0.46       0.33      0.165
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#       8/59    0.587G   0.03783   0.02597   0.02309   0.08689         6       640: 100% 439/439 [00:27<00:00, 16.09it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 63/63 [00:02<00:00, 28.10it/s]
#                  all        250        454      0.431       0.46      0.392      0.203
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#       9/59    0.587G   0.03609   0.02652   0.02061   0.08322         5       640: 100% 439/439 [00:27<00:00, 16.04it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 63/63 [00:02<00:00, 27.65it/s]
#                  all        250        454      0.389      0.505      0.396       0.21
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      10/59    0.587G   0.03674   0.02603   0.02016   0.08293        12       640: 100% 439/439 [00:27<00:00, 16.07it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 63/63 [00:02<00:00, 27.89it/s]
#                  all        250        454      0.437      0.475      0.439      0.217
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      11/59    0.587G   0.03646   0.02541   0.01992   0.08179         9       640: 100% 439/439 [00:27<00:00, 16.10it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 63/63 [00:02<00:00, 27.67it/s]
#                  all        250        454      0.556       0.43      0.424      0.226
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      12/59    0.587G   0.03636   0.02567   0.01993   0.08196         6       640: 100% 439/439 [00:27<00:00, 16.05it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 63/63 [00:02<00:00, 27.95it/s]
#                  all        250        454      0.418      0.477      0.392      0.212
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      13/59    0.587G   0.03431   0.02506   0.01841   0.07778         6       640: 100% 439/439 [00:27<00:00, 16.17it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 63/63 [00:02<00:00, 28.18it/s]
#                  all        250        454      0.458      0.488      0.422      0.224
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      14/59    0.587G   0.03381   0.02417   0.01828   0.07625         5       640: 100% 439/439 [00:27<00:00, 16.25it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 63/63 [00:02<00:00, 28.62it/s]
#                  all        250        454      0.487      0.455      0.431      0.254
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      15/59    0.587G   0.03493   0.02491   0.01756    0.0774         4       640: 100% 439/439 [00:27<00:00, 16.10it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 63/63 [00:02<00:00, 28.07it/s]
#                  all        250        454      0.524      0.508      0.448      0.249
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      16/59    0.587G   0.03316   0.02509   0.01656   0.07481        12       640: 100% 439/439 [00:27<00:00, 16.03it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 63/63 [00:02<00:00, 28.27it/s]
#                  all        250        454      0.459      0.593      0.481      0.258
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      17/59    0.587G   0.03327   0.02406   0.01717    0.0745         9       640: 100% 439/439 [00:27<00:00, 15.85it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 63/63 [00:02<00:00, 27.81it/s]
#                  all        250        454       0.52      0.497      0.489      0.261
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      18/59    0.587G   0.03174    0.0247   0.01614   0.07258         6       640: 100% 439/439 [00:28<00:00, 15.63it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 63/63 [00:02<00:00, 27.49it/s]
#                  all        250        454      0.576       0.52      0.526      0.301
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      19/59    0.587G   0.03198   0.02452   0.01615   0.07265         6       640: 100% 439/439 [00:27<00:00, 15.74it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 63/63 [00:02<00:00, 28.08it/s]
#                  all        250        454      0.443      0.516      0.446      0.248
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      20/59    0.587G    0.0317   0.02427   0.01459   0.07056        16       640: 100% 439/439 [00:28<00:00, 15.58it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 63/63 [00:02<00:00, 27.73it/s]
#                  all        250        454      0.533      0.448       0.47      0.268
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      21/59    0.587G    0.0323   0.02348   0.01415   0.06993         5       640: 100% 439/439 [00:27<00:00, 16.10it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 63/63 [00:02<00:00, 27.75it/s]
#                  all        250        454      0.636      0.455      0.522      0.284
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      22/59    0.587G    0.0305   0.02312   0.01461   0.06823         7       640: 100% 439/439 [00:28<00:00, 15.34it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 63/63 [00:02<00:00, 27.28it/s]
#                  all        250        454      0.432      0.501      0.464      0.261
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      23/59    0.587G   0.03149   0.02341   0.01339   0.06829         7       640: 100% 439/439 [00:28<00:00, 15.26it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 63/63 [00:02<00:00, 27.28it/s]
#                  all        250        454      0.465      0.443      0.402      0.232
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      24/59    0.587G   0.03062   0.02346   0.01497   0.06905         3       640: 100% 439/439 [00:28<00:00, 15.61it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 63/63 [00:02<00:00, 26.31it/s]
#                  all        250        454      0.464      0.531       0.45      0.255
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      25/59    0.587G   0.03008   0.02334   0.01441   0.06784         5       640: 100% 439/439 [00:27<00:00, 15.95it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 63/63 [00:02<00:00, 27.74it/s]
#                  all        250        454      0.556      0.503      0.514      0.302
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      26/59    0.587G   0.03091   0.02421   0.01269   0.06781         5       640: 100% 439/439 [00:27<00:00, 15.72it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 63/63 [00:02<00:00, 28.08it/s]
#                  all        250        454      0.483      0.614      0.497      0.291
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      27/59    0.587G   0.02963   0.02203   0.01289   0.06455         3       640: 100% 439/439 [00:27<00:00, 15.90it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 63/63 [00:02<00:00, 27.40it/s]
#                  all        250        454      0.546       0.58      0.502      0.307
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      28/59    0.587G    0.0296   0.02305   0.01277   0.06542         8       640: 100% 439/439 [00:27<00:00, 15.72it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 63/63 [00:02<00:00, 28.71it/s]
#                  all        250        454      0.635      0.463      0.477      0.284
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      29/59    0.587G   0.02907    0.0218     0.012   0.06287         6       640: 100% 439/439 [00:28<00:00, 15.63it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 63/63 [00:02<00:00, 28.46it/s]
#                  all        250        454       0.53      0.524      0.484      0.296
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      30/59    0.587G   0.02745   0.02115   0.01217   0.06078         5       640: 100% 439/439 [00:27<00:00, 15.71it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 63/63 [00:02<00:00, 28.42it/s]
#                  all        250        454      0.463      0.556       0.48       0.28
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      31/59    0.587G   0.02794   0.02187   0.01144   0.06125         5       640: 100% 439/439 [00:27<00:00, 15.80it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 63/63 [00:02<00:00, 28.32it/s]
#                  all        250        454      0.641      0.475      0.524      0.329
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      32/59    0.587G   0.02802   0.02206    0.0111   0.06117         5       640: 100% 439/439 [00:27<00:00, 15.70it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 63/63 [00:02<00:00, 28.05it/s]
#                  all        250        454       0.57      0.582      0.563      0.338
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      33/59    0.587G   0.02677   0.02105  0.009889   0.05771        14       640: 100% 439/439 [00:27<00:00, 16.08it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 63/63 [00:02<00:00, 28.49it/s]
#                  all        250        454      0.638      0.527       0.57      0.338
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      34/59    0.587G    0.0264    0.0216   0.01003   0.05804         7       640: 100% 439/439 [00:27<00:00, 15.90it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 63/63 [00:02<00:00, 27.11it/s]
#                  all        250        454      0.608      0.553      0.524      0.322
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      35/59    0.587G   0.02626   0.02076   0.01004   0.05706         4       640: 100% 439/439 [00:27<00:00, 15.92it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 63/63 [00:02<00:00, 27.99it/s]
#                  all        250        454       0.67      0.514      0.557      0.339
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      36/59    0.587G   0.02668   0.02056   0.00949   0.05673         7       640: 100% 439/439 [00:28<00:00, 15.63it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 63/63 [00:02<00:00, 28.49it/s]
#                  all        250        454      0.638      0.556      0.533      0.327
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      37/59    0.587G    0.0262    0.0203  0.009736   0.05624         9       640: 100% 439/439 [00:27<00:00, 16.02it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 63/63 [00:02<00:00, 28.39it/s]
#                  all        250        454      0.597      0.555      0.527      0.322
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      38/59    0.587G   0.02635   0.01982  0.009137    0.0553        11       640: 100% 439/439 [00:28<00:00, 15.52it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 63/63 [00:02<00:00, 28.17it/s]
#                  all        250        454      0.591      0.593      0.534       0.33
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      39/59    0.587G    0.0263   0.02023  0.009778    0.0563         3       640: 100% 439/439 [00:28<00:00, 15.53it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 63/63 [00:02<00:00, 28.25it/s]
#                  all        250        454      0.563      0.621      0.536      0.331
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      40/59    0.587G   0.02481      0.02  0.008959   0.05377         4       640: 100% 439/439 [00:28<00:00, 15.54it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 63/63 [00:02<00:00, 28.22it/s]
#                  all        250        454      0.598       0.55      0.531      0.344
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      41/59    0.587G   0.02516   0.01981  0.008785   0.05375         6       640: 100% 439/439 [00:27<00:00, 15.80it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 63/63 [00:02<00:00, 27.92it/s]
#                  all        250        454      0.541      0.591      0.526      0.322
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      42/59    0.587G   0.02462   0.02022   0.00844   0.05328        10       640: 100% 439/439 [00:27<00:00, 15.94it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 63/63 [00:02<00:00, 28.48it/s]
#                  all        250        454      0.563      0.588      0.549      0.346
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      43/59    0.587G   0.02443   0.01986  0.008047   0.05234         4       640: 100% 439/439 [00:27<00:00, 15.68it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 63/63 [00:02<00:00, 27.58it/s]
#                  all        250        454      0.552      0.588      0.548      0.363
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      44/59    0.587G   0.02325   0.01855   0.00895   0.05075         7       640: 100% 439/439 [00:27<00:00, 15.74it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 63/63 [00:02<00:00, 27.77it/s]
#                  all        250        454      0.659       0.59      0.557      0.352
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      45/59    0.587G   0.02337   0.01835  0.007698   0.04942         5       640: 100% 439/439 [00:27<00:00, 15.86it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 63/63 [00:02<00:00, 27.00it/s]
#                  all        250        454      0.628       0.54      0.535      0.345
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      46/59    0.587G    0.0231   0.01809  0.007314    0.0485         6       640: 100% 439/439 [00:28<00:00, 15.66it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 63/63 [00:02<00:00, 27.99it/s]
#                  all        250        454       0.63      0.553      0.554      0.336
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      47/59    0.587G   0.02368   0.01873  0.007361   0.04976         4       640: 100% 439/439 [00:27<00:00, 15.90it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 63/63 [00:02<00:00, 26.78it/s]
#                  all        250        454      0.613      0.539      0.526      0.347
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      48/59    0.587G   0.02294   0.01833  0.007395   0.04866         4       640: 100% 439/439 [00:27<00:00, 15.87it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 63/63 [00:02<00:00, 28.88it/s]
#                  all        250        454      0.575      0.554       0.54      0.355
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      49/59    0.587G   0.02301   0.01851   0.00673   0.04825         8       640: 100% 439/439 [00:28<00:00, 15.64it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 63/63 [00:02<00:00, 28.17it/s]
#                  all        250        454      0.646      0.512      0.548      0.361
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      50/59    0.587G   0.02234   0.01787  0.007215   0.04743         5       640: 100% 439/439 [00:27<00:00, 15.84it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 63/63 [00:02<00:00, 28.21it/s]
#                  all        250        454      0.633      0.548      0.539      0.362
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      51/59    0.587G   0.02262   0.01877  0.007183   0.04858         9       640: 100% 439/439 [00:27<00:00, 16.14it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 63/63 [00:02<00:00, 28.56it/s]
#                  all        250        454      0.633      0.582      0.544      0.367
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      52/59    0.587G   0.02192    0.0181  0.007149   0.04717         4       640: 100% 439/439 [00:28<00:00, 15.62it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 63/63 [00:02<00:00, 28.27it/s]
#                  all        250        454      0.564      0.569      0.513      0.345
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      53/59    0.587G   0.02207   0.01871  0.006216     0.047         1       640: 100% 439/439 [00:27<00:00, 15.71it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 63/63 [00:02<00:00, 28.22it/s]
#                  all        250        454      0.647      0.552      0.536      0.356
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      54/59    0.587G   0.02162   0.01734  0.006292   0.04525         8       640: 100% 439/439 [00:28<00:00, 15.53it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 63/63 [00:02<00:00, 27.82it/s]
#                  all        250        454      0.654      0.503      0.517      0.336
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      55/59    0.587G   0.02132   0.01724  0.006892   0.04544         9       640: 100% 439/439 [00:28<00:00, 15.42it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 63/63 [00:02<00:00, 27.26it/s]
#                  all        250        454      0.699      0.532      0.561      0.373
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      56/59    0.587G   0.02109   0.01757  0.006512   0.04517         7       640: 100% 439/439 [00:28<00:00, 15.23it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 63/63 [00:02<00:00, 28.26it/s]
#                  all        250        454      0.605      0.583      0.554      0.364
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      57/59    0.587G   0.02115   0.01786   0.00572   0.04473         2       640: 100% 439/439 [00:28<00:00, 15.26it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 63/63 [00:02<00:00, 27.82it/s]
#                  all        250        454      0.627      0.544       0.55      0.382
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      58/59    0.587G   0.02197    0.0181   0.00572   0.04579         7       640: 100% 439/439 [00:28<00:00, 15.30it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 63/63 [00:02<00:00, 27.40it/s]
#                  all        250        454      0.695      0.529      0.549      0.368
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      59/59    0.587G   0.02131    0.0172  0.005811   0.04432        11       640: 100% 439/439 [00:28<00:00, 15.36it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 63/63 [00:02<00:00, 21.79it/s]
#                  all        250        454      0.657      0.564      0.554      0.372
#            Ambulance        250         64      0.787      0.844      0.854      0.633
#                  Bus        250         46      0.672      0.625      0.628      0.438
#                  Car        250        238       0.56       0.42      0.408      0.251
#           Motorcycle        250         46      0.535      0.565      0.494      0.273
#                Truck        250         60      0.733      0.367      0.389      0.265
# 60 epochs completed in 0.509 hours.
#
# Optimizer stripped from runs/train/exp6/weights/last.pt, 14.4MB
# Optimizer stripped from runs/train/exp6/weights/best.pt, 14.4MB

# %% [markdown]
# # 4. Visualize

# %% [markdown]
# ## Weights & Biases Logging 🌟 NEW
#
# [Weights & Biases](https://wandb.ai/site?utm_campaign=repo_yolo_notebook) (W&B) is now integrated with YOLOv5 for real-time visualization and cloud logging of training runs. This allows for better run comparison and introspection, as well improved visibility and collaboration for teams. To enable W&B `pip install wandb`, and then train normally (you will be guided through setup on first use).
#
# During training you will see live updates at [https://wandb.ai/home](https://wandb.ai/home?utm_campaign=repo_yolo_notebook), and you can create and share detailed [Reports](https://wandb.ai/glenn-jocher/yolov5_tutorial/reports/YOLOv5-COCO128-Tutorial-Results--VmlldzozMDI5OTY) of your results. For more information see the [YOLOv5 Weights & Biases Tutorial](https://github.com/ultralytics/yolov5/issues/1289).
#
# <img src="https://user-images.githubusercontent.com/26833433/98184457-bd3da580-1f0a-11eb-8461-95d908a71893.jpg" width="800">

# %% [markdown]
# ## Local Logging
#
# All results are logged by default to `runs/train`, with a new experiment directory created for each new training as `runs/train/exp2`, `runs/train/exp3`, etc. View train and test jpgs to see mosaics, labels, predictions and augmentation effects. Note a **Mosaic Dataloader** is used for training (shown below), a new concept developed by Ultralytics and first featured in [YOLOv4](https://arxiv.org/abs/2004.10934).

# %%
Image(filename='runs/train/exp/train_batch0.jpg', width=800)  # train batch 0 mosaics and labels
Image(filename='runs/train/exp/test_batch0_labels.jpg', width=800)  # test batch 0 labels
Image(filename='runs/train/exp/test_batch0_pred.jpg', width=800)  # test batch 0 predictions

# %% [markdown]
# > <img src="https://user-images.githubusercontent.com/26833433/83667642-90fcb200-a583-11ea-8fa3-338bbf7da194.jpeg" width="750">
# `train_batch0.jpg` shows train batch 0 mosaics and labels
#
# > <img src="https://user-images.githubusercontent.com/26833433/83667626-8c37fe00-a583-11ea-997b-0923fe59b29b.jpeg" width="750">
# `test_batch0_labels.jpg` shows test batch 0 labels
#
# > <img src="https://user-images.githubusercontent.com/26833433/83667635-90641b80-a583-11ea-8075-606316cebb9c.jpeg" width="750">
# `test_batch0_pred.jpg` shows test batch 0 _predictions_

# %% [markdown]
# Training results are automatically logged to [Tensorboard](https://www.tensorflow.org/tensorboard) and `runs/train/exp/results.txt`, which is plotted as `results.png` (below) after training completes. You can also plot any `results.txt` file manually:

# %%
from utils.plots import plot_results 
plot_results(save_dir='runs/train/exp')  # plot all results*.txt files in 'runs/train/exp'
Image(filename='runs/train/exp/results.png', width=800)

# %% [markdown]
# <p align="left"><img width="800" alt="COCO128 Training Results" src="https://github.com/ultralytics/yolov5/releases/download/v1.0/results_COCO128.png"></p>

# %% [markdown]
# # Environments
#
# YOLOv5 may be run in any of the following up-to-date verified environments (with all dependencies including [CUDA](https://developer.nvidia.com/cuda)/[CUDNN](https://developer.nvidia.com/cudnn), [Python](https://www.python.org/) and [PyTorch](https://pytorch.org/) preinstalled):
#
# - **Google Colab and Kaggle** notebooks with free GPU: <a href="https://colab.research.google.com/github/ultralytics/yolov5/blob/master/tutorial.ipynb"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"></a> <a href="https://www.kaggle.com/ultralytics/yolov5"><img src="https://kaggle.com/static/images/open-in-kaggle.svg" alt="Open In Kaggle"></a>
# - **Google Cloud** Deep Learning VM. See [GCP Quickstart Guide](https://github.com/ultralytics/yolov5/wiki/GCP-Quickstart)
# - **Amazon** Deep Learning AMI. See [AWS Quickstart Guide](https://github.com/ultralytics/yolov5/wiki/AWS-Quickstart)
# - **Docker Image**. See [Docker Quickstart Guide](https://github.com/ultralytics/yolov5/wiki/Docker-Quickstart) <a href="https://hub.docker.com/r/ultralytics/yolov5"><img src="https://img.shields.io/docker/pulls/ultralytics/yolov5?logo=docker" alt="Docker Pulls"></a>

# %% [markdown]
# # Status
#
# ![CI CPU testing](https://github.com/ultralytics/yolov5/workflows/CI%20CPU%20testing/badge.svg)
#
# If this badge is green, all [YOLOv5 GitHub Actions](https://github.com/ultralytics/yolov5/actions) Continuous Integration (CI) tests are currently passing. CI tests verify correct operation of YOLOv5 training ([train.py](https://github.com/ultralytics/yolov5/blob/master/train.py)), testing ([test.py](https://github.com/ultralytics/yolov5/blob/master/test.py)), inference ([detect.py](https://github.com/ultralytics/yolov5/blob/master/detect.py)) and export ([export.py](https://github.com/ultralytics/yolov5/blob/master/export.py)) on MacOS, Windows, and Ubuntu every 24 hours and on every commit.

# %% [markdown]
# # Appendix
#
# Optional extras below. Unit tests validate repo functionality and should be run on any PRs submitted.

# %%
# Reproduce
for x in 'yolov5s', 'yolov5m', 'yolov5l', 'yolov5x':
  # !python test.py --weights {x}.pt --data coco.yaml --img 640 --conf 0.25 --iou 0.45  # speed
  # !python test.py --weights {x}.pt --data coco.yaml --img 640 --conf 0.001 --iou 0.65  # mAP

# %%
# PyTorch Hub
import torch

# Model
model = torch.hub.load('ultralytics/yolov5', 'yolov5s')

# Images
dir = 'https://github.com/ultralytics/yolov5/raw/master/data/images/'
imgs = [dir + f for f in ('zidane.jpg', 'bus.jpg')]  # batch of images

# Inference
results = model(imgs)
results.print()  # or .show(), .save()

# %%
# Unit tests
# %%shell
export PYTHONPATH="$PWD"  # to run *.py. files in subdirectories

rm -rf runs  # remove runs/
for m in yolov5s; do  # models
  python train.py --weights $m.pt --epochs 3 --img 320 --device 0  # train pretrained
  python train.py --weights '' --cfg $m.yaml --epochs 3 --img 320 --device 0  # train scratch
  for d in 0 cpu; do  # devices
    python detect.py --weights $m.pt --device $d  # detect official
    python detect.py --weights runs/train/exp/weights/best.pt --device $d  # detect custom
    python test.py --weights $m.pt --device $d # test official
    python test.py --weights runs/train/exp/weights/best.pt --device $d # test custom
  done
  python hubconf.py  # hub
  python models/yolo.py --cfg $m.yaml  # inspect
  python export.py --weights $m.pt --img 640 --batch 1  # export
done

# %%
# Profile
from utils.torch_utils import profile 

m1 = lambda x: x * torch.sigmoid(x)
m2 = torch.nn.SiLU()
profile(x=torch.randn(16, 3, 640, 640), ops=[m1, m2], n=100)

# %%
# Evolve
# !python train.py --img 640 --batch 64 --epochs 100 --data coco128.yaml --weights yolov5s.pt --cache --noautoanchor --evolve
# !d=runs/train/evolve && cp evolve.* $d && zip -r evolve.zip $d && gsutil mv evolve.zip gs://bucket  # upload results (optional)

# %%
# VOC
for b, m in zip([64, 48, 32, 16], ['yolov5s', 'yolov5m', 'yolov5l', 'yolov5x']):  # zip(batch_size, model)
  # !python train.py --batch {b} --weights {m}.pt --data VOC.yaml --epochs 50 --cache --img 512 --nosave --hyp hyp.finetune.yaml --project VOC --name {m}
